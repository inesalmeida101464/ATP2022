# %%
def menu():
    print("""
    (1) Criar Lista 
    (2) Ler Lista
    (3) Soma
    (4) Média
    (5) Maior
    (6) Menor
    (7) estaOrdenada por ordem crescente
    (8) estaOrdenada por ordem decrescente
    (9) Procura um elemento
    (0) Sair""")
    return menu
  
menu()
opcao=int(input("Selecione uma opção do menu abaixo"))
    
while opcao!=0:
    if opcao == 1 :
        lista = []
        comp= int(input("Defina o número de elementos da sua lista"))
        import random 
        while len(lista)< comp:
            i=random.randint(0,100)
            lista.append(i)
        print("A lista é ", lista)
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))

    if opcao == 2 :
        N=int(input("Defina o número de elementos da sua lista"))
        lista=[]
        i=0
        while (i<N):
            num= int(input("Introduza um número na sua lista"))
            lista.append (num)
            i=i+1
        print (lista)
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))
    
    if opcao == 3:
        soma=0
        for i in lista:
            soma=soma+i
        print("A soma dos elementos da lista é", soma)
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))

    if opcao == 4:
        soma=0
        for i in lista:
            soma= soma+i
            media=soma/len(lista)
        print("A média dos números da lista é", media)
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))

    if opcao== 5:
        maior=lista[0]
        for i in lista:
            if i>maior:
                maior=i
    
        print("O maior numero da lista é", maior)
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))

    if opcao== 6 :
        menor=lista[0]
        for i in lista :
            if i<menor:
                menor=i
        print("O menor número da lista é", menor)
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))

    if opcao == 7:
        i=0
        res=True
        while (i<len(lista)-1):
            if lista[i]<=lista[i+1]:
                res=True
            if not lista[i]<=lista[i+1]:
                res= False
            i=i+1
            
        if res== True:
            print("Sim")

        elif res== False:
            print("Não")
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))
    
    if opcao == 8:      
        i=0 
        res=True                                   
        while(i<len(lista)-1):
            if lista[i]>=lista[i+1]:
                res=True
            if not lista[i]>=lista[i+1]:
                res=False
            i=i+1

        if res== True:
            print("Sim")

        if res== False:
            print("Não")
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))

    if opcao == 9:
        elem=int(input("Introduza o elemento da lista que pretende procurar"))
        for i in lista:
            if i==elem:
                lista.index(elem)
                print("O elemento está na posiçao",lista.index(elem))
        if elem not in lista:
            print("O elemento não está na lista")
        menu()
        opcao=int(input("Selecione uma opção do menu abaixo"))

if opcao==0:
    print("Terminou o programa. A lista apresentada é", lista)
# Out:
#     (1) Criar Lista
#     (2) Ler Lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) estaOrdenada por ordem crescente
#     (8) estaOrdenada por ordem decrescente
#     (9) Procura um elemento
#     (0) Sair
# A lista é  [16, 13, 27, 69, 30, 78, 97, 8]
#
#     (1) Criar Lista
#     (2) Ler Lista
#     (3) Soma
#     (4) Média
#     (5) Maior
#     (6) Menor
#     (7) estaOrdenada por ordem crescente
#     (8) estaOrdenada por ordem decrescente
#     (9) Procura um elemento
#     (0) Sair
# Terminou o programa. A lista apresentada é [16, 13, 27, 69, 30, 78, 97, 8]
